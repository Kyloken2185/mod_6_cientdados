# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('dados.csv')

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
df1 = df.copy()

# %%
# Gráfico de barras com a variável APGAR1
fig = plt.figure()
sns.countplot(x = 'APGAR1', data = df1)
# Out:
# <Axes: xlabel='APGAR1', ylabel='count'>

# %%
# Gráfico de barras com a variável APGAR5
fig = plt.figure()
sns.countplot(x = 'APGAR5', data = df1)
# Out:
# <Axes: xlabel='APGAR5', ylabel='count'>

# %%
# Gráfico de barras com a variável SEXO
fig = plt.figure()
sns.countplot(x = 'SEXO', data = df1)
# Out:
# <Axes: xlabel='SEXO', ylabel='count'>

# %%
# Gráfico de barras com a variável GESTACAO
fig = plt.figure()
sns.countplot(x = 'GESTACAO', data = df1)
# Out:
# <Axes: xlabel='GESTACAO', ylabel='count'>

# %%
# Gráfico de barras com a variável ESTCIVMAE:
fig = plt.figure()
ax = sns.countplot(x = 'ESTCIVMAE', data = df1)

# Mudando as categorias no eixo x e rotacionando em 30 graus:
ax.set_xticklabels(['Solteira', 'Casada', 'Viúva', 'Separado judicialmente/Divorciado', 'União consensual', 'Ignorado'])
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
# Criando a variável 'APGAR5_MED_CONSULTAS' 
df1['APGAR5_MED_CONSULTAS']= df1['APGAR5'].mean()/df1['CONSULTAS']

# Criando o gráfico de barras da variável 'APGAR5_MED_CONSULTAS'
ax = sns.countplot(x = 'APGAR5_MED_CONSULTAS', data = df1)
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
# Criando a figura que vai comportar os gráficos requeridos:
plt.rc('figure', figsize = (12, 10))
fig, axes = plt.subplots(2, 2)

# Construção simultânea dos gráficos das variáveis SEXO, GESTACAO, ESTCIVMAE e CONSULTAS:
sns.countplot(ax = axes[0,0], x = 'SEXO', data = df1)
sns.countplot(ax = axes[0,1], x = 'GESTACAO', data = df1)
sns.countplot(ax = axes[1,0], x = 'ESTCIVMAE', data = df1)
sns.countplot(ax = axes[1,1], x = 'CONSULTAS', data = df1)

# Rotacionando os labels do eixo x de cada gráfico
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45)
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45)
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45)
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45)

# Exibir o gráfico
plt.tight_layout()
plt.show()
